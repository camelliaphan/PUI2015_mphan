# %% [markdown]
# # I want you to create a <i>reproducible research</i> code
# that means we want the reader to be able to reproduce every step of our analysis. when stochastic processes and random variables are involved that gets tricky, but since computers are unable to rpoduce truly random numbers, we can actually reproduce every series of "pseudo random" number generated by a computer as long as we know what seed is used. <i>The first seed will determin entirely the distribution that is generated, and the seeds of the following distriburions generated by the code!</i>

# %%
import os
import sys

# %% [markdown]
# #THIS IS THE MOST IMPORTANT PIECE OF THIS CODE!
# ##we must give numpy as seed for this code to be reproducible
# http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.seed.html

# %%
import numpy as np
np.random.seed(2709)

# %% [markdown]
# ##use this function to generate 100 2-dimensional random datapoints in a gaussian distribution in 2 dimensions
#
# http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.randn.html

# %%
x1 = np.random.randn(100,2)
print x1
print x1.mean()
# Out:
# [[-0.4968737  -0.92060228]
#  [ 1.1504448  -0.73505688]
#  [ 0.03122572  0.02966395]
#  [-1.5623866  -1.36078879]
#  [-0.36107293  1.379129  ]
#  [ 2.28626664  0.37718099]
#  [ 1.02667237  0.02912454]
#  [ 0.26963665 -0.54025612]
#  [-1.98986758  0.56836686]
#  [ 0.29823654 -1.33976321]
#  [-1.32465636  0.29641466]
#  [-2.06855008  0.03362167]
#  [ 0.05354475  0.39171907]
#  [ 0.25425011 -1.04094005]
#  [-0.22408265 -0.40911786]
#  [-1.28003126  1.02534751]
#  [ 0.26824773  0.8014226 ]
#  [ 0.11245378  0.08170123]
#  [ 1.37078316 -0.10652898]
#  [-1.48712015 -1.00590168]
#  [ 0.25659718  1.2788888 ]
#  [-1.04836835  1.53895778]
#  [ 1.46937429  0.28803655]
#  [-1.71078265  2.81091977]
#  [ 1.2727786  -0.05079859]
#  [ 1.63550376 -1.22002923]
#  [ 0.44622829  0.55356608]
#  [-0.03989904  0.83251183]
#  [-1.04590272  0.65291869]
#  [ 0.34492437 -0.14892364]
#  [ 0.20555398  2.56468081]
#  [-0.35939879  0.499115  ]
#  [ 0.5891001  -0.42390832]
#  [-2.028474   -1.07322688]
#  [ 0.4804457  -0.91244171]
#  [ 0.68690224  0.65415556]
#  [ 0.90325427 -0.12752116]
#  [ 1.50975888 -1.59367959]
#  [-0.1526262  -0.0975225 ]
#  [-0.72652248 -0.78420602]
#  [-0.62356359  2.16970203]
#  [ 0.74458319  0.64099963]
#  [ 1.21439623 -0.22466516]
#  [-0.25049526 -1.83415859]
#  [-1.01456136  1.47429941]
#  [-1.19162605 -0.01629867]
#  [-0.73148359 -0.48670205]
#  [ 0.89541198 -0.78748809]
#  [ 0.2799248  -1.09071364]
#  [ 2.00158116 -2.60954201]
#  [-1.29523884  0.19449945]
#  [ 0.46959712  0.20010249]
#  [ 1.22720985  0.17789218]
#  [ 0.00473894  0.61593685]
#  [-0.08766415 -3.02380612]
#  [-0.59868257  0.21466751]
#  [-0.06139914 -0.19556935]
#  [-0.096519    1.36004446]
#  [-0.70845644 -1.45530094]
#  [ 1.08094762  0.19160339]
#  [-0.98873555 -0.57388279]
#  [ 1.09601926  0.81527231]
#  [-0.73492845  2.45399379]
#  [ 0.33644384  1.68869693]
#  [-0.73805208 -1.60999304]
#  [ 0.0729392  -0.75504302]
#  [ 0.39985567  1.19460361]
#  [ 0.13460056 -0.45330426]
#  [ 0.26594303 -0.55061689]
#  [ 0.31862565 -1.97465485]
#  [-0.39061885  0.99465973]
#  [ 1.94925706 -1.03360971]
#  [ 2.34863903  1.28024792]
#  [ 0.28368967  0.16520214]
#  [ 0.6621523  -0.58564455]
#  [-0.50587099  1.15992832]
#  [ 0.52333763  1.52491946]
#  [-0.90776256  0.52174701]
#  [-0.34708239  0.70896791]
#  [-0.63354568 -0.32407378]
#  [-1.94194933  0.18646894]
#  [-0.37340441 -0.81622899]
#  [-1.42679377  1.25604559]
#  [ 0.60323213  1.32339518]
#  [-0.77542415 -0.60276775]
#  [ 0.142457   -0.58085804]
#  [-0.88145754 -0.10566572]
#  [-0.13025084  0.80203277]
#  [ 1.05697182  0.26819789]
#  [ 0.42739733 -1.51481762]
#  [ 2.36862096 -0.61383751]
#  [-1.16153218  0.39005896]
#  [ 0.0879391   0.67491152]
#  [-0.16224472  0.01284162]
#  [ 0.33188538 -0.15064973]
#  [ 0.41744769 -0.86588707]
#  [-0.05446749 -1.87600934]
#  [-0.39410433  0.15084989]
#  [-0.74628456  0.22932621]
#  [-0.28365729 -1.17024029]]
# 0.00239935695766

# %% [markdown]
# ## use the same function to generate 50 more random objects, but this time change the mean
# to do that you multiply the distribution by a different sigma, and add your new mean - remember that these are 2D objects, so yor mean must be a 2D vector (a list, an array or a tuple)!

# %%
#I just chose a random number here to multiply the distribution, 
#and a random mean. Is that what the assignment is supposed to be?

x2 = 1.5*np.random.randn(50,2)+(2.5, 2.5)
print x2
# Out:
# [[ 1.4906862   4.53769975]
#  [ 3.44096637  3.54212633]
#  [ 0.27892911  3.61688782]
#  [ 3.34917479  1.52072504]
#  [-1.11476077  1.49629882]
#  [ 1.07440018  2.13106234]
#  [ 2.53609856 -1.28889499]
#  [ 1.9092223   5.6892939 ]
#  [ 1.54894026  2.95499958]
#  [ 2.03226203  0.68898718]
#  [ 2.82887021  4.46455779]
#  [ 4.01027858  0.99571054]
#  [ 0.33595544  3.78268081]
#  [ 3.7865521   3.88876052]
#  [ 4.62857034  0.75358576]
#  [ 2.22134996  2.62047993]
#  [ 4.28554073  3.70885076]
#  [ 3.91428457  2.4782063 ]
#  [ 2.08365893  1.04584431]
#  [ 2.37932192  3.72440691]
#  [ 2.36469737  3.393674  ]
#  [ 3.02122537  3.24226401]
#  [ 3.27079405  4.26929564]
#  [ 1.57176614  5.17073208]
#  [ 4.88178357  2.75384079]
#  [ 2.19499937  3.62793381]
#  [ 3.4762318   3.94220216]
#  [ 3.24027585 -0.42749193]
#  [ 0.25080823  2.61320335]
#  [ 0.06902035  2.41225098]
#  [ 3.07837767  1.88185182]
#  [ 0.30939908  4.35808329]
#  [ 4.11443919  2.83409285]
#  [ 4.25085543  3.82057223]
#  [-0.40822757  1.81273052]
#  [ 0.23638836  3.16301774]
#  [ 1.84346815  2.93618686]
#  [ 5.42845405  4.71698472]
#  [ 2.56693588 -0.74170751]
#  [ 3.00536241  1.3875954 ]
#  [ 1.95911385  2.44743792]
#  [ 2.38105361  1.69579316]
#  [ 1.70011712  2.35996893]
#  [ 2.1358505   4.76042634]
#  [ 4.09372555  4.50589971]
#  [ 1.44351804  3.83685674]
#  [ 3.59603798  4.72783076]
#  [ 3.59195984  3.4911907 ]
#  [ 2.39271997  2.48602015]
#  [ 4.43221402  4.85517181]]

# %% [markdown]
# ##now plot them with this function:
#
# https://scipy-lectures.github.io/intro/matplotlib/matplotlib.html#scatter-plots
#
# ##if you print the array it will be a 2x100: 100 2D objects. although that is what we wanted we cannot plot it easily this way: there are many ways to deal with it. the goal is to pass the first dimension as the disrt argument to scatter, and the second dimension as the second argument. i am gonna do it by transposing the array (switching the axes)

# %%
import matplotlib.pyplot as plt 
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x1 = x1.T #switch from 2D objects to arrays of variables 
x2 = x2.T 
plt.scatter(x1[0], x1[1])
plt.hold(True)
plt.scatter(x2[0], x2[1])

# %% [markdown]
# ##first plot them as a single distribution, then change the color for the 2 samples
#
# remember to give your labels some names and to make a legend! in the legend tell me what the mean and standard deviation of each sample is

# %%
plt.scatter(x1[0], x1[1], color = "blue")
plt.hold(True)
plt.scatter(x2[0], x2[1], color = "red")
