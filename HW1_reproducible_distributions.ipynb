# %% [markdown]
# # I want you to create a <i>reproducible research</i> code
# that means we want the reader to be able to reproduce every step of our analysis. when stochastic processes and random variables are involved that gets tricky, but since computers are unable to rpoduce truly random numbers, we can actually reproduce every series of "pseudo random" number generated by a computer as long as we know what seed is used. <i>The first seed will determin entirely the distribution that is generated, and the seeds of the following distriburions generated by the code!</i>

# %%
import os
import sys

# %% [markdown]
# #THIS IS THE MOST IMPORTANT PIECE OF THIS CODE!
# ##we must give numpy as seed for this code to be reproducible
# http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.seed.html

# %%
import numpy as np
np.random.seed(seed=None)

# %% [markdown]
# ##use this function to generate 100 2-dimensional random datapoints in a gaussian distribution in 2 dimensions
#
# http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.randn.html

# %%
x1 = np.random.randn(100,2)
print x1
print x1.mean()
# Out:
# [[ 0.6517312   0.2543464 ]
#  [-0.57962074 -0.85247862]
#  [-0.06981844  0.99307699]
#  [-0.85208651 -1.0088679 ]
#  [-1.20223387 -0.3354706 ]
#  [ 1.08287038  1.59156307]
#  [-0.72779716 -0.19284046]
#  [ 2.03375715  0.38208739]
#  [ 2.26120424 -0.63289691]
#  [-1.13535439 -0.89291798]
#  [ 0.68910479 -1.24038902]
#  [ 0.31817421  0.02713534]
#  [-1.27862908  0.57909409]
#  [ 1.0942659  -1.63843569]
#  [-1.20095361  0.40731833]
#  [ 1.18112039 -1.94045681]
#  [-1.35325139  0.34877748]
#  [ 1.06388513  1.67788943]
#  [-0.06903542  0.0205378 ]
#  [ 0.02672188 -0.41670143]
#  [-0.07582168 -1.08157711]
#  [-1.61441385 -0.10933695]
#  [-0.45539628  0.89364183]
#  [ 0.26377215 -0.42530164]
#  [-1.48207258  0.48348657]
#  [ 1.04837161 -1.0415528 ]
#  [-1.92898343  0.24622362]
#  [-1.30759812 -0.67244681]
#  [ 0.62985085  0.10255396]
#  [ 0.47857391 -0.69204529]
#  [-0.45539263 -1.30416755]
#  [ 0.25071929 -0.63534912]
#  [ 0.08198581 -0.71755211]
#  [-1.03239414  0.0286215 ]
#  [-0.76511764  0.41654618]
#  [-0.60099532  0.13197858]
#  [ 1.40091622 -0.31356649]
#  [ 0.32607165 -0.77981731]
#  [-0.3039428  -1.61013875]
#  [-0.95218539 -0.18508344]
#  [ 0.26439787 -1.15399252]
#  [-0.48961835  1.0253636 ]
#  [-0.6035588  -0.16948076]
#  [ 0.09864998 -0.17509416]
#  [-0.96519653 -0.48465992]
#  [-0.52107581 -0.40861329]
#  [-0.77256297 -0.51155529]
#  [ 0.89697961  0.96932657]
#  [ 1.79403198  0.26799217]
#  [-0.39637416  1.61849674]
#  [ 0.91809875  1.40932567]
#  [-0.07153611 -0.01342645]
#  [ 1.21798172  0.33345362]
#  [ 1.10948378  1.53502998]
#  [ 1.04732231  0.03784601]
#  [ 0.419648   -0.88038147]
#  [-0.51856812  0.19283594]
#  [ 1.32855015 -0.62999914]
#  [-0.92858786 -0.48904986]
#  [ 0.73364834 -1.24575541]
#  [ 0.55864742  2.18360511]
#  [ 0.11797569  0.46959175]
#  [ 0.39878682  0.49780473]
#  [ 0.06090694  1.03885587]
#  [-0.4746863   1.32001854]
#  [ 1.94163614 -1.12613315]
#  [-0.77090186  1.98097317]
#  [ 2.89516194  0.68680598]
#  [ 0.36239669 -1.29592766]
#  [-1.4002346   0.38645176]
#  [-1.35893919 -1.39169528]
#  [-1.32193231  0.34992719]
#  [-0.55784608  0.36584027]
#  [-0.69819521 -0.48933265]
#  [ 0.39554649  0.03838282]
#  [ 0.88293499  0.03194385]
#  [ 0.82773331 -0.64085301]
#  [-0.93314774 -2.5463812 ]
#  [ 2.44523946 -1.79156735]
#  [ 1.60945863 -0.51065168]
#  [-0.45915223  0.3113688 ]
#  [ 0.20301569  1.70327621]
#  [ 2.01300033  2.18401821]
#  [ 0.33223081 -0.05996303]
#  [ 0.04819287  1.55602213]
#  [-0.0675243   0.41102735]
#  [ 3.05018747 -0.87839015]
#  [-1.16681253 -1.04954968]
#  [-1.63800455  1.55222134]
#  [ 0.72989684  0.44030982]
#  [-0.65761148  1.89585796]
#  [ 0.80933632  2.91350443]
#  [ 0.7879353  -2.06128382]
#  [ 0.24789884  2.17916777]
#  [ 0.66927539  0.00793671]
#  [ 1.73342472 -0.24300341]
#  [-0.5028943  -0.96464508]
#  [ 1.45660007  0.19922661]
#  [ 0.27800707 -0.87527361]
#  [ 0.93158022 -1.13818484]]
# 0.0625764621933

# %% [markdown]
# ## use the same function to generate 50 more random objects, but this time change the mean
# to do that you multiply the distribution by a different sigma, and add your new mean - remember that these are 2D objects, so yor mean must be a 2D vector (a list, an array or a tuple)!

# %%
#I just chose a random number here to multiply the distribution, 
#and a random mean. Is that what the assignment is supposed to be?

x2 = 1.5*np.random.randn(50,2)+(2.5, 2.5)
print x2
# Out:
# [[ 0.14541036  2.23754245]
#  [ 0.49236079  3.70986143]
#  [ 1.10460859  3.2858924 ]
#  [ 0.10761137  1.40483391]
#  [ 7.26212805  2.77976114]
#  [ 3.14256313  1.03824477]
#  [ 3.38537806  3.46003786]
#  [ 0.74812359  5.17086469]
#  [ 3.28090777  3.15018287]
#  [ 1.81438156  4.40211685]
#  [ 3.35568699  1.04391907]
#  [ 1.04643618  2.4241371 ]
#  [ 4.1828737   0.94320886]
#  [ 1.37633454  1.78062368]
#  [-0.08580255  2.78059077]
#  [ 2.0898719   1.24256417]
#  [ 1.72579418  3.12158133]
#  [ 3.0981288   3.80849647]
#  [ 2.25614828  2.59756702]
#  [ 3.6194001   3.11291153]
#  [ 4.94014553  5.04112991]
#  [ 5.11206111  1.72302171]
#  [ 1.12353419  2.33564449]
#  [ 1.77538921  0.27120059]
#  [ 1.94421241  1.19372221]
#  [ 4.62950638  1.7466109 ]
#  [ 1.14076135  1.54019641]
#  [ 1.76219388  2.68481947]
#  [ 3.95043797  3.03716046]
#  [ 1.29024731  2.01442749]
#  [ 2.96651414  2.63442892]
#  [ 2.02775433  2.17796116]
#  [ 0.35667187  2.16852739]
#  [ 4.80901264  1.97985022]
#  [ 1.23841824  2.47403656]
#  [ 3.58316581  2.57096728]
#  [ 0.6967581   1.17603163]
#  [ 1.92443406  0.82640891]
#  [ 4.18347679  4.28874631]
#  [ 3.90073218  1.10986791]
#  [ 2.93578829  3.98087213]
#  [-1.39614266 -1.2486461 ]
#  [ 0.98628598  0.63903809]
#  [ 2.4984171   2.5657503 ]
#  [ 4.51023973  1.87240193]
#  [ 1.97568026  2.29216932]
#  [ 3.49165565  3.91278056]
#  [ 4.347147    2.82151174]
#  [ 3.63042511  3.83319326]
#  [ 0.05735516  2.83748459]]

# %% [markdown]
# ##now plot them with this function:
#
# https://scipy-lectures.github.io/intro/matplotlib/matplotlib.html#scatter-plots
#
# ##if you print the array it will be a 2x100: 100 2D objects. although that is what we wanted we cannot plot it easily this way: there are many ways to deal with it. the goal is to pass the first dimension as the disrt argument to scatter, and the second dimension as the second argument. i am gonna do it by transposing the array (switching the axes)

# %%
import matplotlib.pyplot as plt 
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x1 = x1.T #switch from 2D objects to arrays of variables 
x2 = x2.T 
plt.scatter(x1[0], x1[1])
plt.hold(True)
plt.scatter(x2[0], x2[1])

# %% [markdown]
# ##first plot them as a single distribution, then change the color for the 2 samples
#
# remember to give your labels some names and to make a legend! in the legend tell me what the mean and standard deviation of each sample is

# %%
plt.scatter(x1[0], x1[1], color = "blue")
plt.hold(True)
plt.scatter(x2[0], x2[1], color = "red")
# is there anything wrong with this plot? It does not look so right to me.
